# %% [markdown]
# * **Librerias**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data_set=pd.read_csv("Spotify-2000.csv")
data_set
# Out:
#       Index                   Title                    Artist  \
# 0         1                 Sunrise               Norah Jones
# 1         2             Black Night               Deep Purple
# 2         3          Clint Eastwood                  Gorillaz
# 3         4           The Pretender              Foo Fighters
# 4         5  Waitin' On A Sunny Day         Bruce Springsteen
# ...     ...                     ...                       ...
# 1989   1990        Heartbreak Hotel             Elvis Presley
# 1990   1991               Hound Dog             Elvis Presley
# 1991   1992         Johnny B. Goode               Chuck Berry
# 1992   1993               Take Five  The Dave Brubeck Quartet
# 1993   1994          Blueberry Hill               Fats Domino
#
#                 Top Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 0         adult standards  2004                     157      30            53
# ...

# %% [markdown]
# * **Nombre de las columnas**

# %%
data_set.columns
# Out:
# Index(['Index', 'Title', 'Artist', 'Top Genre', 'Year',
#        'Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)',
#        'Liveness', 'Valence', 'Length (Duration)', 'Acousticness',
#        'Speechiness', 'Popularity'],
#       dtype='object')

# %% [markdown]
# * **La correlación entre las variables**

# %%
f,ax=plt.subplots(figsize=(11,11))
sns.heatmap(data_set.corr(),annot=True,linewidths=0.5,ax=ax,fmt=".2f")

# %%
data_set.describe()
# Out:
#              Index         Year  Beats Per Minute (BPM)       Energy  \
# count  1994.000000  1994.000000             1994.000000  1994.000000
# mean    997.500000  1992.992979              120.215647    59.679539
# std     575.762538    16.116048               28.028096    22.154322
# min       1.000000  1956.000000               37.000000     3.000000
# 25%     499.250000  1979.000000               99.000000    42.000000
# 50%     997.500000  1993.000000              119.000000    61.000000
# 75%    1495.750000  2007.000000              136.000000    78.000000
# max    1994.000000  2019.000000              206.000000   100.000000
#
#        Danceability  Loudness (dB)     Liveness      Valence  \
# count   1994.000000    1994.000000  1994.000000  1994.000000
# mean      53.238215      -9.008526    19.012036    49.408726
# std       15.351507       3.647876    16.727378    24.858212
# min       10.000000     -27.000000     2.000000     3.000000
# ...

# %%
sns.pairplot(data_set[["Loudness (dB)","Beats Per Minute (BPM)","Energy","Danceability"]])

# %% [markdown]
#  ## 1.-  Visualización de artist

# %%
data_set['Artist'].value_counts().plot.bar()

# %% [markdown]
# * **Esta grafica es dificil de intrepretar por la gran cantidad de datos por lo que nos limitaremos a poner el top 30**

# %%
print(data_set["Artist"].value_counts().head(30).plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(data_set["Artist"].value_counts().head(10))
# Out:
# Queen                 37
# The Beatles           36
# Coldplay              27
# U2                    26
# The Rolling Stones    24
# Bruce Springsteen     23
# Michael Jackson       23
# ABBA                  22
# David Bowie           21
# Fleetwood Mac         18
# Name: Artist, dtype: int64

# %% [markdown]
#  ## 2.-  Visualización de Top Generos

# %%
data_set['Top Genre'].value_counts().plot.bar()

# %% [markdown]
# * **Esta grafica es dificil de intrepretar por la gran cantidad de datos por lo que nos limitaremos a poner el top 30**

# %%
print(data_set['Top Genre'].value_counts().head(30).plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# * **En esta grafica se aprecian mucho mejor los datos**
#
# Por lo que concluimos que el top 10 seria:

# %% [markdown]
# ## 3.- Visualización de Beats Per Minute (BPM)

# %%
data_set['Beats Per Minute (BPM)'].plot.hist()

# %% [markdown]
# ## 4.- Visualización de Energy

# %%
data_set['Energy'].plot.hist()

# %% [markdown]
# ## 5.- Visualización de Danceability

# %%
data_set['Danceability'].plot.hist()

# %% [markdown]
# ## 6.- Visualización Loudness (dB)

# %%
data_set['Loudness (dB)'].plot.hist()

# %% [markdown]
# ## 7.- Visualización de Liveness

# %%
data_set["Liveness"].plot.hist()

# %% [markdown]
# ## 8.- Visualización de Valence

# %%
data_set["Valence"].plot.hist()

# %% [markdown]
# ## 9.- Visualización de Length (Duration)

# %%
data_set["Length (Duration)"].plot.hist()

# %% [markdown]
# ## 10.- Visualización de Acousticness

# %%
data_set['Acousticness'].plot.hist()

# %% [markdown]
# ## 11.- Visualización de Speechiness

# %%
data_set['Speechiness'].plot.hist()

# %% [markdown]
# ## 12.- Visualización de Popularity

# %%
data_set['Popularity'].plot.hist()

# %% [markdown]
# **Cambiar el nombre a una columna**

# %%
data_set.rename(columns = {'Top Genre':'Top Generos'})
# Out:
#       Index                   Title                    Artist  \
# 0         1                 Sunrise               Norah Jones
# 1         2             Black Night               Deep Purple
# 2         3          Clint Eastwood                  Gorillaz
# 3         4           The Pretender              Foo Fighters
# 4         5  Waitin' On A Sunny Day         Bruce Springsteen
# ...     ...                     ...                       ...
# 1989   1990        Heartbreak Hotel             Elvis Presley
# 1990   1991               Hound Dog             Elvis Presley
# 1991   1992         Johnny B. Goode               Chuck Berry
# 1992   1993               Take Five  The Dave Brubeck Quartet
# 1993   1994          Blueberry Hill               Fats Domino
#
#               Top Generos  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 0         adult standards  2004                     157      30            53
# ...
